# %% [markdown]
# <a href="https://colab.research.google.com/github/alstj003/2024-intro-DA-code/blob/main/w01_2_intro_DA_for_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터분석입문
# ## 01주 코딩

# %% [markdown]
# ### 코랩을 위한 주피터 노트북 기초
#
# - 한글 처리
# - 데이터 시각화 기초

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 64.8 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt

plt.title("데이터 시각화의 한글 준비와 기본 직선 그래프")
plt.plot([10, 5, 25, 30])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("데이터 시각화의 한글 준비와 기본 직선 그래프")
plt.plot([0, 1, 2, 3], [10, 5, 25, 30])
plt.show()

# %% [markdown]
# #### end of code

# %%
import pandas as pd

pop = pd.read_csv("202311popmonth.csv", encoding='cp949', index_col=0,
                  thousands=',')
pop
# Out:
#                        2023년11월_총인구수  2023년11월_세대수  2023년11월_세대당 인구  \
# 행정구역
# 전국  (1000000000)            51337076      23904793             2.15
# 서울특별시  (1100000000)          9390925       4469374             2.10
# 부산광역시  (2600000000)          3295496       1564199             2.11
# 대구광역시  (2700000000)          2376044       1093499             2.17
# 인천광역시  (2800000000)          2993492       1347984             2.22
# 광주광역시  (2900000000)          1420822        655552             2.17
# 대전광역시  (3000000000)          1443106        680226             2.12
# 울산광역시  (3100000000)          1103752        490174             2.25
# 세종특별자치시  (3600000000)         386256        160764             2.40
# 경기도  (4100000000)           13628135       5974055             2.28
# 강원특별자치도  (5100000000)        1528635        760636             2.01
# 충청북도  (4300000000)           1594038        779978             2.04
# 충청남도  (4400000000)           2129591       1034508             2.06
# ...

# %%
pop.columns = ['총인구수', '세대수', '세대당인구', '남자인구수', '여자인구수', '남여비율']
pop.head()
# Out:
#                          총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 행정구역
# 전국  (1000000000)     51337076  23904793   2.15  25572695  25764381  0.99
# 서울특별시  (1100000000)   9390925   4469374   2.10   4543055   4847870  0.94
# 부산광역시  (2600000000)   3295496   1564199   2.11   1606680   1688816  0.95
# 대구광역시  (2700000000)   2376044   1093499   2.17   1167480   1208564  0.97
# 인천광역시  (2800000000)   2993492   1347984   2.22   1497231   1496261  1.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(
# ...

# %%
pop.index = [pop.index[i].split()[0] for i in range(len(pop))]
pop
# Out:
#              총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 전국       51337076  23904793   2.15  25572695  25764381  0.99
# 서울특별시     9390925   4469374   2.10   4543055   4847870  0.94
# 부산광역시     3295496   1564199   2.11   1606680   1688816  0.95
# 대구광역시     2376044   1093499   2.17   1167480   1208564  0.97
# 인천광역시     2993492   1347984   2.22   1497231   1496261  1.00
# 광주광역시     1420822    655552   2.17    701645    719177  0.98
# 대전광역시     1443106    680226   2.12    719805    723301  1.00
# 울산광역시     1103752    490174   2.25    567145    536607  1.06
# 세종특별자치시    386256    160764   2.40    192396    193860  0.99
# 경기도      13628135   5974055   2.28   6855041   6773094  1.01
# 강원특별자치도   1528635    760636   2.01    768910    759725  1.01
# 충청북도      1594038    779978   2.04    810734    783304  1.04
# 충청남도      2129591   1034508   2.06   1091095   1038496  1.05
# 전라북도      1756183    861263   2.04    874078    882105  0.99
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(pop['총인구수'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53945 (\N{HANGUL SYLLABLE TEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index, y='총인구수', data=pop1)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53945 (\N{HANGUL SYLLABLE TEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
